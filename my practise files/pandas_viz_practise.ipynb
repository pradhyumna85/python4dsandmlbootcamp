# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
# %load_ext nb_black
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline
# Out:
# The nb_black extension is already loaded. To reload it, use:
#   %reload_ext nb_black

# %%
df1 = pd.read_csv("df1")

# %%
df1.rename(columns={"Unnamed: 0": "Date"}, inplace=True)

# %%
df1.set_index("Date", inplace=True)

# %%
df1.head()
# Out:
#                    A         B         C         D
# Date
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("df2")

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
sns.set_style("darkgrid")
df1["A"].hist(bins=30)

# %%
df1["A"].plot(kind="hist", bins=20)

# %%
df1["A"].plot.hist()

# %%
df2  # small data frame
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1["A"].plot.hist(bins=50)

# %%
sns.distplot(df1["A"], kde=True)  # directly using seaborn

# %%
df1.head()
# Out:
#                    A         B         C         D
# Date
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1 = pd.read_csv("df1", index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.index
# Out:
# Index(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04', '2000-01-05',
#        '2000-01-06', '2000-01-07', '2000-01-08', '2000-01-09', '2000-01-10',
#        ...
#        '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20', '2002-09-21',
#        '2002-09-22', '2002-09-23', '2002-09-24', '2002-09-25', '2002-09-26'],
#       dtype='object', length=1000)

# %%
df1.plot.line(y="B", figsize=(18, 6), lw=1) #if x is not index then specify explicitly

# %%
df1.plot.scatter(x="A", y="B")

# %%
df1.plot.scatter(x="A", y="B", c="C")

# %%
fig, ax = plt.subplots()  # for missing x label and ticks (bug in pandas)
df1.plot.scatter(x="A", y="B", c="C", cmap="coolwarm", ax=ax)

# %%
df1.plot.scatter(x="A", y="B", s=df1["C"] * 6)  # 's' is for size according to  C column

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=["a", "b"])

# %%
df.head()
# Out:
#           a         b
# 0 -1.386330  1.029080
# 1  0.556015  0.805193
# 2  1.871396  0.827064
# 3 -0.450917 -0.596055
# 4 -0.967959  1.772566

# %%
np.random.randn(1000, 2)
# Out:
# array([[-1.00997631, -2.11058047],
#        [-0.030856  , -0.12875987],
#        [ 0.41321006, -0.78468274],
#        ...,
#        [ 0.92369314, -0.28945234],
#        [ 0.83169449, -1.4882402 ],
#        [-0.536483  ,  1.68959101]])

# %%
fig, ax = plt.subplots()
df.plot.hexbin(x="a", y="b", gridsize=20, cmap="coolwarm", ax=ax)

# %%
fig, ax = plt.subplots()
df.plot.hexbin(x="a", y="b", gridsize=20, ax=ax)

# %%
df2["a"].plot.kde()

# %%
df2["a"].plot.density()

# %%
df2.plot.kde()
